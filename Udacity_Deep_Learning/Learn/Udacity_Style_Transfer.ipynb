# %% [markdown]
# <a href="https://colab.research.google.com/github/VigneshwaraChinnadurai/DL_Works/blob/master/Udacity_Deep_Learning/Learn/Udacity_Style_Transfer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow scipy pillow
# Out:
# ...
#      |████████████████████████████████| 462 kB 10.0 MB/s
# ...

# %%
# !pip install moviepy

# %%
# !python -c "import imageio; imageio.plugins.ffmpeg.download()"
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %%
# !git clone https://github.com/lengstrom/fast-style-transfer.git
# Out:
# Cloning into 'fast-style-transfer'...
# remote: Enumerating objects: 248, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 248 (delta 2), reused 5 (delta 0), pack-reused 238
# Receiving objects: 100% (248/248), 11.02 MiB | 17.75 MiB/s, done.
# Resolving deltas: 100% (113/113), done.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-a4edeb9c-5b01-490a-b347-afb9bbbcdadb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a4edeb9c-5b01-490a-b347-afb9bbbcdadb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 20220101_160940.jpg to 20220101_160940.jpg
# User uploaded file "20220101_160940.jpg" with length 7958605 bytes

# %%
# !mv 20220101_160940.jpg fast-style-transfer/20220101_160940.jpg

# %%
# !mv rain-princess.ckpt fast-style-transfer/rain-princess.ckpt

# %%
import os
os.chdir('./fast-style-transfer')
print(os.getcwd())
# Out:
# /content/fast-style-transfer

# %%
# !python evaluate.py --checkpoint ./rain-princess.ckpt --in-path ./20220101_160940.jpg --out-path ./output_image.jpg
# Out:
# 2022-04-05 18:29:02.922010: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-04-05 18:29:03.358195: W tensorflow/core/common_runtime/colocation_graph.cc:1203] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ReadVariableOp: CPU
# AssignVariableOp: CPU
# VarHandleOp: CPU
# VarIsInitializedOp: CPU
#
# ...
